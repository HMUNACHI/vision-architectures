# %%
from arch.vgg import VGG
from arch.resnet import WideResNet
from arch.googlenet import GoogLeNet
from arch.dataloader import load_data

# %load_ext autotime

# %% [markdown]
# # VGG Main

# %%
# Load Data MNIST
batch_size = 100
train_loader, test_loader, valid_loader = load_data('MNIST', batch_size)
# Out:
# Train: 60000
# Test: 10000
# Image structure: (100, 1, 32, 32)
# time: 1.15 s (started: 2021-04-25 17:58:11 +00:00)

# %%
# Create Model
model = VGG(arch='VGG16', 
            channels=1, 
            num_classes=10)

print(model)
print("No of parmeter:",sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# VGG(
#   (convs): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
# ...

# %%
# Train Model With Early Stopping
train(model,
      train_loader, 
      valid_loader, 
      epochs=50,
      name='vgg16_mnist.pt')
# Out:
# Epoch: 1 	Training Loss: 1.519695 	Validation Loss: 1.032984
# Validation loss decreased (inf --> 1.032984).  Saving model ...
# Epoch: 2 	Training Loss: 0.718840 	Validation Loss: 0.537401
# Validation loss decreased (1.032984 --> 0.537401).  Saving model ...
# Epoch: 3 	Training Loss: 0.517267 	Validation Loss: 0.287810
# Validation loss decreased (0.537401 --> 0.287810).  Saving model ...
# Epoch: 4 	Training Loss: 0.341490 	Validation Loss: 0.227533
# Validation loss decreased (0.287810 --> 0.227533).  Saving model ...
# Epoch: 5 	Training Loss: 0.262816 	Validation Loss: 0.213715
# Validation loss decreased (0.227533 --> 0.213715).  Saving model ...
# Epoch: 6 	Training Loss: 0.226823 	Validation Loss: 0.218859
# Epoch: 7 	Training Loss: 0.220878 	Validation Loss: 0.144112
# Validation loss decreased (0.213715 --> 0.144112).  Saving model ...
# Epoch: 8 	Training Loss: 0.211850 	Validation Loss: 0.147838
# Epoch: 9 	Training Loss: 0.177854 	Validation Loss: 0.151883
# ...

# %%
# Test Model
test(model, 
     test_loader, 
     name='vgg16_mnist.pt',
     batch_size = batch_size)
# Out:
# Test Loss: 0.044682
#
# Test Accuracy of     0: 99% (978/980)
# Test Accuracy of     1: 99% (1132/1135)
# Test Accuracy of     2: 98% (1018/1032)
# Test Accuracy of     3: 99% (1004/1010)
# Test Accuracy of     4: 99% (975/982)
# Test Accuracy of     5: 97% (873/892)
# Test Accuracy of     6: 97% (932/958)
# Test Accuracy of     7: 99% (1019/1028)
# Test Accuracy of     8: 99% (968/974)
# Test Accuracy of     9: 99% (1005/1009)
#
# Test Accuracy (Overall): 99% (9904/10000)
# time: 6.07 s (started: 2021-04-25 18:41:15 +00:00)

# %%
# Load Data
batch_size = 100
train_loader, test_loader, valid_loader = load_data('CIFAR10', batch_size)
# Out:
# ...
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Train: 50000
# Test: 10000
# Image structure: (100, 3, 32, 32)
# time: 8.21 s (started: 2021-04-26 18:21:14 +00:00)

# %%
# Create Model
model = VGG(arch='VGG16', 
            channels=3, 
            num_classes=10)

print(model)
# Out:
# VGG(
#   (convs): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
# ...

# %%
# Train Model With Early Stopping
train(model, 
      train_loader, 
      valid_loader, 
      epochs=100,
      name='vgg16_cifar10.pt')
# Out:
# Epoch: 1 	Training Loss: 2.045406 	Validation Loss: 1.952649
# Validation loss decreased (inf --> 1.952649).  Saving model ...
# Epoch: 2 	Training Loss: 1.855841 	Validation Loss: 2.096480
# Epoch: 3 	Training Loss: 1.746558 	Validation Loss: 1.812680
# Validation loss decreased (1.952649 --> 1.812680).  Saving model ...
# Epoch: 4 	Training Loss: 1.574471 	Validation Loss: 1.633526
# Validation loss decreased (1.812680 --> 1.633526).  Saving model ...
# Epoch: 5 	Training Loss: 1.439925 	Validation Loss: 1.448602
# Validation loss decreased (1.633526 --> 1.448602).  Saving model ...
# Epoch: 6 	Training Loss: 1.326193 	Validation Loss: 1.322720
# Validation loss decreased (1.448602 --> 1.322720).  Saving model ...
# Epoch: 7 	Training Loss: 1.209647 	Validation Loss: 1.124419
# Validation loss decreased (1.322720 --> 1.124419).  Saving model ...
# Epoch: 8 	Training Loss: 1.115489 	Validation Loss: 1.116662
# Validation loss decreased (1.124419 --> 1.116662).  Saving model ...
# ...

# %%
# Test Model
test(model, 
     test_loader, 
     name='vgg16_cifar10.pt',
     batch_size=batch_size)
# Out:
# Test Loss: 0.481952
#
# Test Accuracy of     0: 91% (911/1000)
# Test Accuracy of     1: 92% (927/1000)
# Test Accuracy of     2: 80% (807/1000)
# Test Accuracy of     3: 79% (796/1000)
# Test Accuracy of     4: 91% (912/1000)
# Test Accuracy of     5: 78% (788/1000)
# Test Accuracy of     6: 87% (879/1000)
# Test Accuracy of     7: 87% (873/1000)
# Test Accuracy of     8: 90% (905/1000)
# Test Accuracy of     9: 92% (922/1000)
#
# Test Accuracy (Overall): 87% (8720/10000)
# time: 4.79 s (started: 2021-04-26 19:18:32 +00:00)

# %% [markdown]
# # GoogLeNet Main

# %%
# Load Data
batch_size = 100
train_loader, test_loader, valid_loader = load_data('MNIST', batch_size)
# Out:
# Train: 60000
# Test: 10000
# Image structure: (100, 1, 32, 32)
# time: 1.14 s (started: 2021-04-25 23:00:46 +00:00)

# %%
# Create Model
model = GoogLeNet(channels=1)
print(model)
# Out:
# GoogLeNet(
#   (pre_layers): Sequential(
#     (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (a3): Inception(
#     (b1): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (b2): Sequential(
#       (0): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (b3): Sequential(
# ...

# %%
# Train Model With Early Stopping
train(model, 
      train_loader, 
      valid_loader, 
      epochs=50, 
      name='googlenet_mnist.pt')
# Out:
# Epoch: 1 	Training Loss: 0.474756 	Validation Loss: 0.235866
# Validation loss decreased (inf --> 0.235866).  Saving model ...
# Epoch: 2 	Training Loss: 0.110410 	Validation Loss: 0.171602
# Validation loss decreased (0.235866 --> 0.171602).  Saving model ...
# Epoch: 3 	Training Loss: 0.083726 	Validation Loss: 0.141283
# Validation loss decreased (0.171602 --> 0.141283).  Saving model ...
# Epoch: 4 	Training Loss: 0.074378 	Validation Loss: 0.151407
# Epoch: 5 	Training Loss: 0.067750 	Validation Loss: 0.075676
# Validation loss decreased (0.141283 --> 0.075676).  Saving model ...
# Epoch: 6 	Training Loss: 0.059705 	Validation Loss: 0.065817
# Validation loss decreased (0.075676 --> 0.065817).  Saving model ...
# Epoch: 7 	Training Loss: 0.055335 	Validation Loss: 0.068511
# Epoch: 8 	Training Loss: 0.053957 	Validation Loss: 0.055858
# Validation loss decreased (0.065817 --> 0.055858).  Saving model ...
# Epoch: 9 	Training Loss: 0.052741 	Validation Loss: 0.051502
# ...

# %%
# Test Model
test(model, 
     test_loader, 
     name='googlenet_mnist.pt',
     batch_size=batch_size)
# Out:
# Test Loss: 0.032583
#
# Test Accuracy of     0: 99% (978/980)
# Test Accuracy of     1: 99% (1128/1135)
# Test Accuracy of     2: 97% (1008/1032)
# Test Accuracy of     3: 99% (1007/1010)
# Test Accuracy of     4: 99% (975/982)
# Test Accuracy of     5: 98% (880/892)
# Test Accuracy of     6: 97% (938/958)
# Test Accuracy of     7: 99% (1026/1028)
# Test Accuracy of     8: 99% (970/974)
# Test Accuracy of     9: 98% (994/1009)
#
# Test Accuracy (Overall): 99% (9904/10000)
# time: 13.4 s (started: 2021-04-26 01:16:44 +00:00)

# %%
# Load Data
train_loader, test_loader, valid_loader = load_data('CIFAR10', batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train: 50000
# Test: 10000
# Image structure: (100, 3, 32, 32)
# time: 2.8 s (started: 2021-04-26 01:16:58 +00:00)

# %%
# Create Model
model = GoogLeNet(channels=3)
print(model)
# Out:
# GoogLeNet(
#   (pre_layers): Sequential(
#     (0): Conv2d(3, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (a3): Inception(
#     (b1): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (b2): Sequential(
#       (0): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#     (b3): Sequential(
# ...

# %%
# Train Model
train(model, 
      train_loader, 
      valid_loader, 
      epochs=100, 
      name='googlenet_cifar10.pt')
# Out:
# Epoch: 1 	Training Loss: 1.797998 	Validation Loss: 1.530040
# Validation loss decreased (inf --> 1.530040).  Saving model ...
# Epoch: 2 	Training Loss: 1.219956 	Validation Loss: 1.386715
# Validation loss decreased (1.530040 --> 1.386715).  Saving model ...
# Epoch: 3 	Training Loss: 0.941958 	Validation Loss: 1.015910
# Validation loss decreased (1.386715 --> 1.015910).  Saving model ...
# Epoch: 4 	Training Loss: 0.780740 	Validation Loss: 0.729454
# Validation loss decreased (1.015910 --> 0.729454).  Saving model ...
# Epoch: 5 	Training Loss: 0.667933 	Validation Loss: 0.750155
# Epoch: 6 	Training Loss: 0.590681 	Validation Loss: 0.772718
# Epoch: 7 	Training Loss: 0.529690 	Validation Loss: 0.575274
# Validation loss decreased (0.729454 --> 0.575274).  Saving model ...
# Epoch: 8 	Training Loss: 0.486116 	Validation Loss: 0.580873
# Epoch: 9 	Training Loss: 0.446255 	Validation Loss: 0.598825
# Epoch: 10 	Training Loss: 0.408491 	Validation Loss: 0.480747
# ...

# %%
# Test Model
test(model, 
     test_loader, 
     name='googlenet_cifar10.pt',
     batch_size=batch_size)
# Out:
# Test Loss: 0.375508
#
# Test Accuracy of     0: 92% (921/1000)
# Test Accuracy of     1: 96% (960/1000)
# Test Accuracy of     2: 88% (887/1000)
# Test Accuracy of     3: 80% (805/1000)
# Test Accuracy of     4: 90% (900/1000)
# Test Accuracy of     5: 80% (802/1000)
# Test Accuracy of     6: 89% (897/1000)
# Test Accuracy of     7: 95% (954/1000)
# Test Accuracy of     8: 95% (950/1000)
# Test Accuracy of     9: 89% (894/1000)
#
# Test Accuracy (Overall): 89% (8970/10000)
# time: 13.8 s (started: 2021-04-26 05:05:47 +00:00)

# %% [markdown]
# # ResNet Main

# %%
# Load Data
batch_size = 100
train_loader, test_loader, valid_loader = load_data('MNIST', batch_size)
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# ...
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# ...
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# ...
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# ...
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Processing...
# Done!
# ...

# %%
# Create Model
model = WideResNet(channels=1, depth=28, num_classes=10)
print(model)
# Out:
# WideResNet(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (block1): NetworkBlock(
#     (layer): Sequential(
#       (0): BasicBlock(
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (1): BasicBlock(
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# Train Model With Early Stopping
train(model, 
      train_loader, 
      valid_loader, 
      epochs=50, 
      name='resnet_mnist.pt')
# Out:
# Epoch: 1 	Training Loss: 0.328981 	Validation Loss: 0.894210
# Validation loss decreased (inf --> 0.894210).  Saving model ...
# Epoch: 2 	Training Loss: 0.119461 	Validation Loss: 0.113145
# Validation loss decreased (0.894210 --> 0.113145).  Saving model ...
# Epoch: 3 	Training Loss: 0.086903 	Validation Loss: 0.124485
# Epoch: 4 	Training Loss: 0.076666 	Validation Loss: 0.072597
# Validation loss decreased (0.113145 --> 0.072597).  Saving model ...
# Epoch: 5 	Training Loss: 0.066494 	Validation Loss: 0.080168
# Epoch: 6 	Training Loss: 0.057095 	Validation Loss: 0.089729
# Epoch: 7 	Training Loss: 0.056299 	Validation Loss: 0.075080
# Epoch: 8 	Training Loss: 0.050447 	Validation Loss: 0.055518
# Validation loss decreased (0.072597 --> 0.055518).  Saving model ...
# Epoch: 9 	Training Loss: 0.048387 	Validation Loss: 0.066888
# Epoch: 10 	Training Loss: 0.046151 	Validation Loss: 0.057326
# Epoch: 11 	Training Loss: 0.042850 	Validation Loss: 0.056419
# ...

# %%
# Test Model
test(model, 
     test_loader, 
     name='resnet_mnist.pt',
     batch_size=batch_size)
# Out:
# Test Loss: 0.027097
#
# Test Accuracy of     0: 99% (979/980)
# Test Accuracy of     1: 99% (1132/1135)
# Test Accuracy of     2: 98% (1013/1032)
# Test Accuracy of     3: 99% (1004/1010)
# Test Accuracy of     4: 99% (978/982)
# Test Accuracy of     5: 98% (876/892)
# Test Accuracy of     6: 98% (941/958)
# Test Accuracy of     7: 99% (1020/1028)
# Test Accuracy of     8: 99% (970/974)
# Test Accuracy of     9: 99% (1001/1009)
#
# Test Accuracy (Overall): 99% (9914/10000)
# time: 5.82 s (started: 2021-04-27 06:40:37 +00:00)

# %%
# Load Data
train_loader, test_loader, valid_loader = load_data('CIFAR10', batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train: 50000
# Test: 10000
# Image structure: (100, 3, 32, 32)
# time: 2.93 s (started: 2021-04-26 06:12:59 +00:00)

# %%
# Create Model
model = WideResNet(channels=3, depth=28, num_classes=10)
print(model)
# Out:
# WideResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (block1): NetworkBlock(
#     (layer): Sequential(
#       (0): BasicBlock(
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (1): BasicBlock(
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# Train Model With Early Stopping
train(model, 
      train_loader, 
      valid_loader, 
      epochs=100, 
      name='resnet_cifar10.pt')
# Out:
# Epoch: 1 	Training Loss: 1.695886 	Validation Loss: 1.551524
# Validation loss decreased (inf --> 1.551524).  Saving model ...
# Epoch: 2 	Training Loss: 1.255083 	Validation Loss: 1.119166
# Validation loss decreased (1.551524 --> 1.119166).  Saving model ...
# Epoch: 3 	Training Loss: 1.001209 	Validation Loss: 1.038624
# Validation loss decreased (1.119166 --> 1.038624).  Saving model ...
# Epoch: 4 	Training Loss: 0.860384 	Validation Loss: 0.877658
# Validation loss decreased (1.038624 --> 0.877658).  Saving model ...
# Epoch: 5 	Training Loss: 0.754573 	Validation Loss: 0.871738
# Validation loss decreased (0.877658 --> 0.871738).  Saving model ...
# Epoch: 6 	Training Loss: 0.677498 	Validation Loss: 0.726532
# Validation loss decreased (0.871738 --> 0.726532).  Saving model ...
# Epoch: 7 	Training Loss: 0.625232 	Validation Loss: 0.792708
# Epoch: 8 	Training Loss: 0.577023 	Validation Loss: 0.763804
# Epoch: 9 	Training Loss: 0.541015 	Validation Loss: 0.616476
# ...

# %%
# Test Model
test(model,
     test_loader, 
     name='resnet_cifar10.pt',
     batch_size=batch_size)
# Out:
# Test Loss: 0.474883
#
# Test Accuracy of     0: 90% (900/1000)
# Test Accuracy of     1: 96% (961/1000)
# Test Accuracy of     2: 82% (825/1000)
# Test Accuracy of     3: 69% (699/1000)
# Test Accuracy of     4: 86% (868/1000)
# Test Accuracy of     5: 73% (738/1000)
# Test Accuracy of     6: 87% (870/1000)
# Test Accuracy of     7: 89% (896/1000)
# Test Accuracy of     8: 91% (917/1000)
# Test Accuracy of     9: 88% (885/1000)
#
# Test Accuracy (Overall): 85% (8559/10000)
# time: 5.42 s (started: 2021-04-26 07:06:00 +00:00)

# %% [markdown]
# # Explore The Models (Parameters, Size etc)

# %%
from torchvision import models
from torchsummary import summary

# VGG grey
model = VGG(arch='VGG16', 
            channels=1,
            num_classes=10)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
summary(model,(1, 32, 32))
# Out:
# No of parmeter: 14805450
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]             640
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
# ...

# %%
# VGG colour
model = VGG(arch='VGG16', 
            channels=3, 
            num_classes=10)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
summary(model,(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          36,928
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#          MaxPool2d-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#              ReLU-10          [-1, 128, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]         147,584
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
# ...

# %%
# GoogleNet Grey
model = GoogLeNet(channels=1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
summary(model,(1, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 192, 32, 32]           1,920
#        BatchNorm2d-2          [-1, 192, 32, 32]             384
#               ReLU-3          [-1, 192, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          12,352
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 96, 32, 32]          18,528
#        BatchNorm2d-8           [-1, 96, 32, 32]             192
#               ReLU-9           [-1, 96, 32, 32]               0
#            Conv2d-10          [-1, 128, 32, 32]         110,720
#       BatchNorm2d-11          [-1, 128, 32, 32]             256
#              ReLU-12          [-1, 128, 32, 32]               0
#            Conv2d-13           [-1, 16, 32, 32]           3,088
# ...

# %%
# GoogleNet colour
model = GoogLeNet(channels=3)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
summary(model,(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 192, 32, 32]           5,376
#        BatchNorm2d-2          [-1, 192, 32, 32]             384
#               ReLU-3          [-1, 192, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          12,352
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 96, 32, 32]          18,528
#        BatchNorm2d-8           [-1, 96, 32, 32]             192
#               ReLU-9           [-1, 96, 32, 32]               0
#            Conv2d-10          [-1, 128, 32, 32]         110,720
#       BatchNorm2d-11          [-1, 128, 32, 32]             256
#              ReLU-12          [-1, 128, 32, 32]               0
#            Conv2d-13           [-1, 16, 32, 32]           3,088
# ...

# %%
# WideResNet grey
model = WideResNet(channels=1, depth=28, num_classes=10)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
summary(model,(1, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 32, 32]             144
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#             Conv2d-4           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-5           [-1, 16, 32, 32]              32
#               ReLU-6           [-1, 16, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]           2,304
#         BasicBlock-8           [-1, 16, 32, 32]               0
#        BatchNorm2d-9           [-1, 16, 32, 32]              32
#              ReLU-10           [-1, 16, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-12           [-1, 16, 32, 32]              32
#              ReLU-13           [-1, 16, 32, 32]               0
# ...

# %%
# WideResNet colour
model = WideResNet(channels=3, depth=28, num_classes=10)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
summary(model,(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#             Conv2d-4           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-5           [-1, 16, 32, 32]              32
#               ReLU-6           [-1, 16, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]           2,304
#         BasicBlock-8           [-1, 16, 32, 32]               0
#        BatchNorm2d-9           [-1, 16, 32, 32]              32
#              ReLU-10           [-1, 16, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-12           [-1, 16, 32, 32]              32
#              ReLU-13           [-1, 16, 32, 32]               0
# ...
